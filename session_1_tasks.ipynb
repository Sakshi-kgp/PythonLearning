# %% [markdown]
# <a href="https://colab.research.google.com/github/Sakshi-kgp/PythonLearning/blob/Collab-updates/session_1_tasks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Task : Session 1
# Solve these questions own your own and try to test yourself what you have learned in the session.
#
# Happy Learning!

# %% [markdown]
# ### Q1 :- Print the given strings as per stated format.
#
# **Given strings**:
# ```
# "Data" "Science" "Mentorship" "Program"
# "By" "CampusX"
# ```
# **Output**:
# ```
# Data-Science-Mentorship-Program-started-By-CampusX
# ```
#
# Concept- [Seperator and End]

# %%
# Write your code here
print("Data","Science","Mentorship","Program","started","By","CampusX" ,sep="-")
# Out:
# Data-Science-Mentorship-Program-started-By-CampusX

# %% [markdown]
# ### Q2:- Write a program that will convert celsius value to fahrenheit.

# %%
# Write your code here
celsius=float(input("Enter the temp in celsius"))
fa=(celsius*1.8)+32
print(fa)
# Out:
# Enter the temp in celsius23
# 73.4

# %% [markdown]
# ### Q3:- Take 2 numbers as input from the user.Write a program to swap the numbers without using any special python syntax.

# %%
from ast import AnnAssign
# Write your code here
a=int(input("enter first no"))
b=int(input("enter second no"))
temp=a
a=b
b=temp
print(a)
print(b)
# Out:
# enter first no3
# enter second no1
# 1
# 3

# %% [markdown]
# ### Q4:- Write a program to find the euclidean distance between two coordinates.Take both the coordinates from the user as input.

# %%
# Write your code here
import math
x1=int(input("enter  x1"))
y1=int(input("enter y1"))
x2=int(input("enter x2"))
y2=int(input("enter y2"))
d=((x2-x1)**2 +(y2-y1)**2)
d=math.sqrt(d)
print(d)
# Out:
# enter  x13
# enter y15
# enter x25
# enter y27
# 2.8284271247461903

# %% [markdown]
# ### Q5:- Write a program to find the simple interest when the value of principle,rate of interest and time period is provided by the user.

# %%
# Write your code here
p=int(input("enter principle"))
r=int(input("enter rate"))
t=int(input("enter time"))
si=(p*r*t)/100

print(si)
# Out:
# enter principle1000
# enter rate2
# enter tiem34
# 680.0

# %% [markdown]
# ### Q6:- Write a program that will tell the number of dogs and chicken are there when the user will provide the value of total heads and legs.
#
# For example:
# Input:
# heads -> 4
# legs -> 12
# <br>
# Output:
# dogs -> 2
# chicken -> 2

# %%
# Write your code here
heads=int(input("enter heads"))
legs=int(input("enter legs"))
x=(legs-2*heads)/2
y=heads-x
print(x)
print(y)
# Out:
# enter heads4
# enter legs12
# 2.0
# 2.0

# %% [markdown]
# ### Q7:- Write a program to find the sum of squares of first n natural numbers where n will be provided by the user.

# %%
# Write your code heren
n=int(input("enter the value of n"))
ans=(n*(n+1)*(2*n+1))/6
print(f"sum of square of first n natural no is {ans}")
# Out:
# enter the value of n5
# sum of square of first n natural no is 55.0

# %% [markdown]
# ### Q8:- Given the first 2 terms of an Arithmetic Series.Find the Nth term of the series. Assume all inputs are provided by the user.

# %%
# Write your code here
a1=int(input("Enter the first term of ap"))
a2=int(input("enter the second term of ap"))
n=int(input("enter the value of n"))
d=a2-a1
an=a1+(n-1)*d
print(f"nth term is{an}")
# Out:
# Enter the first term of ap2
# enter the second term of ap5
# enter the value of n6
# nth term is17

# %% [markdown]
# ### Q9:- Given 2 fractions, find the sum of those 2 fractions.Take the numerator and denominator values of the fractions from the user.

# %%
# Write your code here
n1=int(input("first numerator"))
d1=int(input("first denomintor"))
n2=int(input("second numerator"))
d2=int(input("second denominator"))
n=n1*d2+n2*d1
d=d1*d2
print(n/d)
# Out:
# first numerator3
# first denomintor6
# second numerator2
# second denominator7
# 0.7857142857142857

# %% [markdown]
# ### Q10:- Given the height, width and breadth of a milk tank, you have to find out how many glasses of milk can be obtained? Assume all the inputs are provided by the user.
#
#
#
# Input:<br>
# Dimensions of the milk tank<br>
# H = 20cm, L = 20cm, B = 20cm
# <br><br>
# Dimensions of the glass<br>
# h = 3cm, r = 1cm

# %%
# Write your code here
h=int(input("inter height"))
l=int(input("inter length"))
b=int(input("inter bredth"))
h1=int(input("inter height of glass"))
r1=int(input("inter radius of glass"))
ans=(l*b*h)/(math.pi*r1**2*h1)
print(ans)
# Out:
# inter height20
# inter length20
# inter bredth20
# inter height of glass3
# inter radius of glass1
# 848.8263631567752
